# %% [markdown]
# # **Creazione e pulizia di un grafo**

# %% [markdown]
# Vista la necessita di manipolare le informazioni sulle relazioni, partendo dai file spacy etichettati nella prima parte del progetto, sono state nuovamente estratte le relazioni seguendo la stessa metodologia.
# Al termine di questo notebook saranno 3 i file estratti:
#  - labels_mapping.json che contiene un dizionario che mappa le diverse entita ed i valori che possono assumere
#  - graph_data.json che contiene le informazioni del nuovo grafo processato, nel formato necessario all'utilizzo della libreria networkx
#  - node_id_text.json che mappa gli id associati ai nodi nel grafo al loro testo

# %% [markdown]
# ## **Support functions:**
#
# - **extract_relations(doc)**: Estrae le relazioni da un documento processato da spaCy. Per ogni frase, estrae le relazioni tra entità e aggiunge l'indice della frase alla tupla della relazione.
#
# - **get_entities_from_adp_new(adps)**: Estrae le entità da una lista di preposizioni (adp) e restituisce una lista di dizionari contenenti il testo e l'etichetta dell'entità.
#
# - **extract_labelled_relations_proj(relations, projectName)**: Estrae le relazioni etichettate da un insieme di relazioni, standardizzando il testo delle entità e creando un dizionario per ogni relazione.

# %%
from Project.relationExtractor import *

def extract_relations(doc):
    relations = []

    for index, sent in enumerate(doc.sents):
        print("Sentence: ", sent.text)
        # Extract relations
        phase_relations = []
        sent_relation = extract_filtered_relations(sent)
        print("Sent relations: ", sent_relation)
        for el in sent_relation:
            #add the sentence index to el tuple
            new_el = el + (index,)

            phase_relations.append(new_el)
            print("Relation: ", new_el)

        relations.append(phase_relations)

    relations = [remove_relative_pronouns(rel) for rel in relations]

    return relations


def get_entities_from_adp_new(adps):
    labels=[]
    for adp in adps:
        adp_text=[]
        adp_label = ""
        for token in adp:
            if token.ent_iob_ != "O":
                adp_text.append(token)
                if adp_label == "":
                    adp_label = token.ent_type_

        #Convert adp_text to string
        adp_text_string=""
        for token in adp_text:
            adp_text_string += token.text + " "
        labels.append({"adp_text": adp_text_string, "label": adp_label})

    return labels


def extract_labelled_relations_proj(relations, projectName):
    relations_return = []
    for relations_group in relations:
        for relation in relations_group:
            #print(f"Relation: {relation}")
            subjects = relation[0]
            entities_subject = get_entities_from_subject(subjects)
            if len(entities_subject["entities"]) == 0:
                continue
            else:
                for label in entities_subject["entities"]:
                    if label["label"] not in not_entity_label:
                        import_label = True
            verb_text = ""
            verb = relation[1]
            if isinstance(verb, list):
                for v in verb:
                    verb_text += v.text + " "
            else:
                verb_text = verb

            # Remove last empty space in
            verb_text = verb_text.strip()
            verb_text = verb_text.replace(" ", "_")
            verb_text = verb_text.replace("/", "")

            objects = relation[2]
            entities_obj = get_entities_from_subject(objects)

            adp_relations = get_entities_from_adp_new(relation[3])

            adp_relations.append({"adp_text": relation[4], "label": "sentencesIndex"})

            adp_relations.append({"adp_text": projectName, "label": "documentName"})

            # Method to unify same word syntax
            entities_subject = standardize_entity_text(entities_subject, False)
            entities_obj = standardize_entity_text(entities_obj, False)
            adp_relations = standardize_entity_text(adp_relations, True)

            # Create the relation dictionary
            relation_dict = [ entities_subject,
                verb_text,
                entities_obj,
                adp_relations]

            #Add the relation to the dictionary
            relations_return.append(relation_dict)

    return relations_return

# %% [markdown]
# ## **Text Extraction from .spacy Files:**
#
# - **Estrazione del testo**: Legge i file .spacy da una directory, li processa con spaCy e estrae le relazioni utilizzando le funzioni di supporto

# %%
import spacy
from Project.graphBuilder import *
import os
nlp = spacy.load("en_core_web_trf")

relations=[]
for root, dirs, files in os.walk("newDocFiles"):
    for file in files:
        filename= file.split(".")[0]
        with open(f"newDocFiles/{file}", "rb") as f:
            doc = spacy.tokens.Doc(nlp.vocab).from_bytes(f.read())

        file_relations= extract_relations(doc)

        relations_dict = extract_labelled_relations_proj(file_relations, filename)

        relations.append(relations_dict)


    break

new_relations = []
for relation in relations:
    for rel in relation:
        new_relations.append(rel)

relations_dict = new_relations

# %% [markdown]
# ## **Cleaning relations:**
#
# - Rimuove le relazioni che non hanno un soggetto valido o che hanno solo etichette specifiche (es. "TIME", "MONEY", ecc.).
# - Rimuove le relazioni che non hanno un oggetto valido o che non hanno preposizioni (adp) valide.

# %%
import re
relations_to_remove = []
label_to_ignore= ["TIME", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL", "PERCENT"]
new_relations = []
date_pattern = r'\b\d{4}\b'
for relation in relations_dict:

    subject = relation[0]
    object = relation[2]
    verb = relation[1]


    adp = relation[3]
    print(f"Relations: ",relation[3])
    adp_file= []
    for el in adp:
        if el['label'] == 'sentencesIndex' or el['label'] == 'documentName':
            adp_file.append(el)

    #remove adp_file from adp
    adp = [el for el in adp if el['label'] != 'sentencesIndex' and el['label'] != 'documentName']


    #Se il soggetto ha solo label "TIME", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL", "PERCENT" --> RIMUOVO
    subject_label = []
    for el in subject['entities']:
        if not el['label'] in label_to_ignore:
            if el['label'] == "DATE" and not re.match(date_pattern, el['entity']):
                continue
            subject_label.append(el)

    object_labels=[]
    for el in object['entities']:
        if not el['label'] in label_to_ignore:
            if el['label'] == "DATE" and not re.match(date_pattern, el['entity']):
                continue
            object_labels.append(el)

    if len(subject_label) == 0:
        relations_to_remove.append(relation)
        continue

    if len(relation) == 4:
        adp_label = []
        for el in adp:
            if not el['label'] in label_to_ignore and el['label'] != "":
                if el['label'] == "DATE" and not re.match(date_pattern, el['adp_text']):
                    continue
                adp_label.append(el)

        #Se non c'è oggetto con label e non ha adp --> RIMUOVO
        #Se c'è oggetto senza label ma adp solo "TIME", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL", "PERCENT" --> RIMUOVO
        if len(adp_label)==0 and len(object_labels) == 0:
            relations_to_remove.append(relation)
            continue

    new_subject = {
        'subject': subject['subject'],
        'entities': subject_label


    }

    new_object = {
        'object': object['subject'],
        'entities': object_labels
    }

    if adp_label:
        new_relations.append([new_subject, relation[1], new_object, adp_label, adp_file])
    else:
        new_relations.append([new_subject, relation[1], new_object, adp_file])

# %% [markdown]
# **Splitting relations**:
#
# - **Creazione di nuove relazioni**: Per ogni relazione, estrae soggetto, oggetto e preposizioni validi e li combina a coppie per creare nuove relazioni.

# %%
splitted_relations = []
rel_counter=0
for relation in new_relations:
    subject = relation[0]
    object = relation[2]
    verb = relation[1]

    adp_file = relation[4]  if len(relation) == 5 else relation[3]

    element=[]

    #Entity to combine
    for entity in object['entities']:
        new_el= {
            'subject': entity['entity'],
            'entities': [entity]
        }
        element.append(new_el)

    for entity in subject['entities']:
        new_el= {
            'subject': entity['entity'],
            'entities': [entity]
        }
        element.append(new_el)

    if len(relation) > 4:
        adp = relation[3]
        for entity in adp:
            new_el= {
                'subject': entity['adp_text'],
                'entities': [{
                    'entity': entity['adp_text'],
                    'label': entity['label']
                }]
            }
            element.append(new_el)

    for i in range(len(element)):
        for j in range(i+1, len(element)):
            new_rel=[
                element[i],
                rel_counter,
                element[j],
                adp_file
            ]
            splitted_relations.append(new_rel)
            rel_counter+=1

# %% [markdown]
# **Cypher Query Creation**:
#
# - **build_Cypher_query_adps(subject, verb, obj, adps)**: Crea query Cypher per aggiungere nodi e relazioni al grafo Neo4j. Le query includono la creazione di nodi e relazioni con proprietà pulite.

# %%
def build_Cypher_query_adps(subject, verb, obj, adps):
    print(f"Subject: {subject}, Verb: {verb}, Object: {obj}, Adps: {adps}")

    # print("Inizio query")
    queries = []

    # Prepare subject labels
    subject_labels = ['Node'] + [entity['label'].strip() for entity in subject['entities']]
    subject_labels_str = ':' + ':'.join(subject_labels)

    # Create subject node with cleaned text
    subject_text = clean_text(subject['subject'].strip())
    subject_query = f"MERGE (s{subject_labels_str} {{text: '{subject_text}'}})"
    queries.append(subject_query)

    # Handle object nodes and relationships
    if obj["subject"]:
        object_query = ""
        object_text = clean_text(obj["subject"].strip())
        # Create object node with cleaned text
        if len(obj["entities"]) != 0:
            object_label = obj["entities"][0]["label"].strip()
            object_query = f"MERGE (o:Node:{object_label} {{text: '{object_text}'}})"
        else:
            object_query = f"MERGE (o:Node {{text: '{object_text}'}})"
        queries.append(object_query)

        # Create relationship with cleaned properties from adps
        properties = {clean_property_key(adp["properties"]): clean_text(adp["adp_text"].strip())
                      for adp in adps if adp["properties"].strip()}  # Skip empty property keys
        props_str = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])

        if len(obj["entities"]) != 0:
            object_label = obj["entities"][0]["label"].strip()
            relationship_query = f"""MATCH (s{subject_labels_str} {{text: '{subject_text}'}})
    MATCH (o:Node:{object_label} {{text: '{object_text}'}})
    MERGE (s)-[r:{verb} {{{props_str}}}]->(o)"""
            queries.append(relationship_query)
        else:
            relationship_query = f"""MATCH (s{subject_labels_str} {{text: '{subject_text}'}})
    MATCH (o:Node {{text: '{object_text}'}})
    MERGE (s)-[r:{verb} {{{props_str}}}]->(o)"""
            queries.append(relationship_query)

    else:
        # Reflexive relationship with cleaned properties
        properties = {clean_property_key(adp["properties"]): clean_text(adp["adp_text"].strip())
                      for adp in adps if adp["properties"].strip()}  # Skip empty property keys
        props_str = ", ".join([f"{k}: '{v}'" for k, v in properties.items()])

        relationship_query = f"""MATCH (s{subject_labels_str} {{text: '{subject_text}'}})
MERGE (s)-[r:{verb} {{{props_str}}}]->(s)"""
        queries.append(relationship_query)

    return queries

# %% [markdown]
# **Graph creation**:
#
# - **Creazione del grafo**: Utilizza le query Cypher per creare il grafo in un database Neo4j. Le relazioni vengono aggiunte al grafo utilizzando le query generate.

# %%
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "14052001"))
session = driver.session()
projectName = "CleanedGraph2"
session.run(f"CREATE DATABASE {projectName}")
project_session=driver.session(database=projectName)

for rel in splitted_relations:
    queries = build_Cypher_query_adps(rel[0], f"REL_{rel[1]}", rel[2], rel[3])

    for q in queries:
        result = project_session.run(q)

# %% [markdown]
# # **Information Extraction from the Graph**
#
# Estrazione di categorie ed entità: Estrae le entità e le categorie dai file .spacy e crea un mapping delle etichette.
#
# - **execute_query(session, labels_mapping)**: Esegue una query Cypher per estrarre l'intero grafo da Neo4j e crea un JSON con i nodi, gli archi e i testi delle relazioni. Elabora il risultato della query che prende da neo4j l'intero grafo, creando il json nella forma:
#
#   *{"nodo1": {"id": 0, "labels": [{"categoria_id": 2, "entita_id": 85}]}, "nodo2": {"id": 0, "labels": [{"categoria_id": 2, "entita_id": 85}]}, "arco": {"id": 1152921504606846976}}*
#
# - **extract_graph_data(session, labels_mapping)**: Estrae i dati del grafo e li organizza in un formato specifico per la creazione del dataset.

# %%
import os
import spacy
from spacy.tokens import Span

labels_mapping = {}
labels_id = 0

directory_path = 'newDocFiles'

nlp = spacy.load("en_core_web_trf")
# Iterate over all folders in the directory

for root, dirs, files in os.walk(directory_path):
    #Iterate on files in the directory
    for file in files:
        if ".spacy" in file and not ".json" in file:
            doc_path = os.path.join(root, file)
            print(f"Processing {doc_path}")
            with open(doc_path, 'rb') as f:
                doc = spacy.tokens.Doc(nlp.vocab).from_bytes(f.read())

            for ent in doc.ents:
                if not ent.label_ in labels_mapping:
                    labels_mapping[ent.label_] = {
                        "id": labels_id,
                        "labels_count": 0,
                        "labels": {}
                    }
                    labels_id += 1
                if not ent.text in labels_mapping[ent.label_]:
                    #if dict have 0 elements
                    labels_mapping[ent.label_]["labels"][ent.text] = labels_mapping[ent.label_]["labels_count"]
                    labels_mapping[ent.label_]["labels_count"] += 1
# Out:
# Processing newDocFiles\COP28TriplingRenewableCapacityPledge.spacy
# Processing newDocFiles\Electricity2024.spacy
# Processing newDocFiles\GlobalCriticalMineralsOutlook2024.spacy
# Processing newDocFiles\IRENAGreenhydrogenderivativestrade2024.spacy
# Processing newDocFiles\Oil2024.spacy
# Processing newDocFiles\Renewables2024.spacy
# Processing newDocFiles\WorldEnergyInvestment2024.spacy
# Processing newDocFiles\WorldEnergyOutlook2024.spacy

# %%
import json

with open('Project/GraphAnalysis/energyReportsGraph/labels_mapping.json', 'w') as f:
    json.dump(labels_mapping, f)

# %%
labels_mapping["GPE"]
# Out:
# {'id': 7,
#  'labels_count': 6380,
#  'labels': {'China': 6344,
#   'Germany': 5419,
#   'Spain': 4935,
#   'Italy': 4937,
#   'France': 6064,
#   'United Kingdom': 5850,
#   'India': 6370,
#   'Japan': 6358,
#   'Brazil': 6041,
#   'Saudi Arabia': 6130,
#   'Egypt': 5689,
#   'Algeria': 3836,
#   'Nigeria': 6080,
#   'South Africa': 6256,
#   'Ethiopia': 5927,
#   'United States': 6379,
#   'Canada': 5833,
#   'Indonesia': 6366,
#   'Philippines': 5932,
#   'Ireland': 4124,
#   'Netherlands': 5501,
#   'Taipei': 3926,
#   'Republic of Türkiye': 74,
#   'Russia': 6179,
#   'Ukraine': 6152,
#   'Denmark': 6063,
#   'Poland': 6047,
#   'Belgium': 6048,
#   'Sweden': 6065,
#   'Portugal': 5457,
#   'Finland': 4938,
#   'Croatia': 3923,
#   'Slovakia': 5460,
#   'Australia': 6099,
#   'Viet Nam': 6367,
#   'Malaysia': 5532,
#   'Thailand': 5788,
#   'New Zealand': 4137,
#   'US': 6010,
#   'Chile': 6040,
#   'Argentina': 6034,
#   'Mexico': 6257,
#   'Eritrea': 183,
#   'Kenya': 5948,
#   'Tanzania': 5944,
#   'Botswana': 4941,
#   'Angola': 4607,
#   'Benin': 203,
#   'Côte d’Ivoire': 3006,
#   'Gabon': 2277,
#   'Rwanda': 5949,
#   'Senegal': 5926,
#   'Niger': 3014,
#   'Sudan': 210,
#   'Azerbaijan': 6174,
#   'Uzbekistan': 6183,
#   'Israel': 3840,
#   'United Arab Emirates': 6105,
#   'Jordan': 6121,
#   'Iraq': 6118,
#   'Tunisia': 235,
#   'Kuwait': 6103,
#   'Morocco': 3880,
#   'Lebanon': 6114,
#   'Libya': 2892,
#   'Qatar': 6129,
#   'Oman': 6106,
#   'Bahrain': 6107,
#   'Abu Dhabi': 1221,
#   'Iran': 6083,
#   'Korea': 6359,
#   'Colombia': 6035,
#   'Costa Rica': 4925,
#   'Türkiye': 5953,
#   'Vietnam': 952,
#   'Pakistan': 5947,
#   'People’s Republic of China': 4465,
#   'Texas': 5864,
#   'Ghana': 6069,
#   'Ludwigshafen': 401,
#   'Slovenia': 558,
#   'Dunkirk': 406,
#   'San Ciprian': 407,
#   'Peine': 417,
#   'Frankfurt': 4232,
#   'London': 5959,
#   'Amsterdam': 450,
#   'Paris': 4501,
#   'Dublin': 1104,
#   'Copenhagen': 461,
#   'Norway': 5540,
#   'Stockholm': 5958,
#   'California': 4406,
#   'Virginia': 484,
#   'Oregon': 4398,
#   'Bangladesh': 5952,
#   'Rooppur': 600,
#   'Loviisa': 555,
#   'Bulgaria': 561,
#   'Kozloduy': 562,
#   'Pomerania': 565,
#   'Florida': 572,
#   'Darlington': 1002,
#   'Ontario': 1005,
#   'Flamanville': 586,
#   'UK': 4433,
#   'Brussels': 610,
#   'Idaho': 993,
#   'Romania': 803,
#   'Michigan': 817,
#   'Saskatchewan': 631,
#   'Czech Republic': 654,
#   'Seversk': 662,
#   'Birr': 691,
#   'Switzerland': 5463,
#   'Greenville': 694,
#   'North Carolina': 879,
#   'Berlin': 1072,
#   'Finspång': 697,
#   'Democratic Republic of the Congo': 6078,
#   'Congo': 725,
#   'South Australia': 762,
#   'Quebec': 1543,
#   'Detroit': 819,
#   'Maine': 825,
#   'Massachusetts': 826,
#   'Gujarat': 901,
#   'Michaung': 833,
#   'Andhra Pradesh': 834,
#   'Karnataka': 900,
#   'Ceara': 848,
#   'Kazakhstan': 6182,
#   'Kyrgyzstan': 6158,
#   'Sri Lanka': 3664,
#   'Madagascar': 6082,
#   'Yemen': 6113,
#   'Hong Kong’s': 872,
#   'Long Island': 873,
#   'Hebei': 892,
#   'Shandong': 3172,
#   'Henan': 894,
#   'Ladakh': 908,
#   'Nepal': 3669,
#   'UAE': 6128,
#   'Singapore': 6364,
#   "Viet Nam's": 941,
#   'Northern Viet Nam': 953,
#   'British Columbia': 1000,
#   'Pickering': 1003,
#   'New York City': 1007,
#   'State of Sao Paulo': 1024,
#   'Ecuador': 3744,
#   'Costa Rica’s': 1042,
#   'Malta': 1050,
#   'Austria': 5955,
#   'Britain': 1091,
#   'Greater Dublin': 1103,
#   'Wales': 1110,
#   'South Korea': 1138,
#   'Belarus': 5679,
#   'Moldova': 1151,
#   'Shirin': 1175,
#   'Turkmenistan': 6172,
#   'Afghanistan': 1179,
#   "Saudi Arabia's": 3164,
#   'Kingdom': 2787,
#   'Dubai': 6100,
#   'Dhafra': 1223,
#   'Mesaieed': 1238,
#   'Ras Laffan': 1239,
#   'Zungeru': 1284,
#   'Uganda': 5941,
#   'Africa': 1916,
#   'APS': 6378,
#   'DRC': 2079,
#   'Peru': 2970,
#   'Udokan': 1490,
#   'Zimbabwe': 6079,
#   'Finniss': 1501,
#   'Albemarle': 1909,
#   'West Australia': 1524,
#   'Kisanfu': 2006,
#   'Balama': 1548,
#   'Mozambique': 6081,
#   'Louisiana': 4777,
#   'Bayan Obo': 2214,
#   'Inner Mongolia': 2155,
#   'Myanmar': 6363,
#   'Laos': 4605,
#   'Kachin state': 2187,
#   'Bolivia': 1878,
#   'Xiangyuan': 1635,
#   'Zambia': 4980,
#   'Namibia': 6071,
#   'European Union’s': 1745,
#   'Estonia': 4259,
#   'us': 5742,
#   'Kamoa Kakula': 2082,
#   'Escondida': 1829,
#   'Oceania': 1834,
#   'Jianxi province': 1849,
#   'Mount Holland': 1858,
#   'Mali': 1886,
#   'New Caledonia': 1963,
#   "New Caledonia's": 1961,
#   'Ruashi': 2007,
#   'Musonoi': 2008,
#   'Mutanda': 2013,
#   'Mutoshi': 2029,
#   'Beira': 2072,
#   'Dar es Salaam': 2088,
#   'Durban': 2074,
#   'Lobito': 3047,
#   'Kolwezi': 2083,
#   'Tazara': 2086,
#   'Pang War Tengchong': 2164,
#   'Kachin State': 2166,
#   'Yunnan Province': 2169,
#   'Menglian': 2177,
#   'Diantan': 2178,
#   'Menglong': 2179,
#   'Jiangxi province': 2184,
#   'Ganzhou': 2183,
#   'Gebeng': 2213,
#   'Birmingham': 2220,
#   'Grenoble': 2221,
#   'Northern Ireland': 2224,
#   'Oklahoma': 2233,
#   'Goiás': 2255,
#   'Yunnan': 2258,
#   'Norilsk': 2309,
#   'ammonia': 2447,
#   'Ammonia': 2446,
#   'Trinidad and Tobago': 2389,
#   'Russian Federation': 6132,
#   'Republic of Korea': 2420,
#   'European Union': 2396,
#   'Jafurah': 6098,
#   'Guyana': 6016,
#   'eurozone': 2641,
#   'America': 2672,
#   'New York': 4400,
#   'Saudi Arabia’s': 4154,
#   'Beijing': 2687,
#   'Riyadh': 2789,
#   'Moscow': 2871,
#   'Suriname': 2964,
#   'Basrah': 2812,
#   'Agogo': 2747,
#   'Surinam': 2752,
#   'Lesedi': 2753,
#   'Neutral Zone': 2826,
#   'Safaniyah': 2785,
#   'Manifa': 2786,
#   'Belbazem': 2803,
#   'Murban': 2804,
#   'Bab': 2805,
#   'Baghdad': 2819,
#   'Zubair': 2814,
#   'West Qurna': 2815,
#   'Ceyhan': 2822,
#   'KRG': 2823,
#   'Tehran': 2859,
#   'Azadegan': 2862,
#   'Yaran': 2856,
#   'Yadavaran': 2858,
#   'Jofeyr': 2860,
#   'Sepehr': 2861,
#   'Saman': 2863,
#   'Delavarn': 2864,
#   'Soomar': 2865,
#   'Masjid Suleiman': 2866,
#   'Suzunskoye': 2872,
#   'Lodochnoye': 2873,
#   'Payakha': 2874,
#   'Ichemminskoye': 2875,
#   'Baikalovskoye': 2876,
#   'Tengiz': 2882,
#   'Okon': 2887,
#   'Venezuela': 5861,
#   'Washington': 4399,
#   'Johan Castberg': 2979,
#   'United Kingdom’s': 2983,
#   'Rosebank': 2984,
#   'Houston': 3082,
#   'Livorno': 3115,
#   'Grangemouth': 3117,
#   'Gelsenkirchen': 4726,
#   'Rhineland': 3119,
#   'Former Soviet Union': 3122,
#   'Novoshakhtinsk': 3128,
#   'Rostov Oblast': 3129,
#   'Seydi': 3131,
#   'Ordabasy': 3133,
#   'Tajikistan': 5067,
#   'Danghara': 3135,
#   'Dangote': 6072,
#   'Tema': 3142,
#   'Sitra': 3153,
#   'Siraf': 3156,
#   'Basra': 3161,
#   'Baiji': 3163,
#   'Jubail': 3165,
#   'Yanbu': 3167,
#   'Yulong': 3174,
#   'Panjin': 3175,
#   'Zhenhai': 3176,
#   'Daxie': 3177,
#   'Hunan': 3178,
#   'Changling': 3179,
#   'Yueyang': 3180,
#   'Yamaguchi': 3186,
#   'Panipat': 3203,
#   'Barauni': 3204,
#   'Koyali': 3205,
#   'Rajasthan': 3206,
#   'Barmer': 3207,
#   'Visakh': 3208,
#   'Balikpapan': 3220,
#   'Sriracha': 3222,
#   'Brunei': 3668,
#   'Mongolia': 5613,
#   'Greece': 4939,
#   'Cambodia': 5929,
#   'Paraguay': 4170,
#   'South Africa’s': 3770,
#   'Scotland': 5325,
#   'England': 4122,
#   'Northeastern States': 4242,
#   'Lithuania': 4261,
#   'Latvia': 4262,
#   'Sierra Leone': 5950,
#   'Panama': 4625,
#   'Manitoba': 4761,
#   'Sines': 4764,
#   'Arizona': 4770,
#   'Iceland': 4775,
#   'Dakar': 4861,
#   'Mauritius': 4942,
#   'Syria': 6112,
#   'Georgia': 6156,
#   'Armenia': 6159,
#   'Kyrgyz Republic': 5073,
#   'Mauritania': 5559,
#   'Slovak Republic': 5682,
#   'São Tomé': 5939,
#   'Príncipe': 5940,
#   'Patagonia': 6042,
#   'Mumbai': 6280,
#   'Pune': 6281,
#   'Maharashtra': 6277,
#   'Amritsar': 6282,
#   'Punjab': 6279}}

# %%
import json

def execute_query(session, labels_mapping):
    try:
        query = "MATCH (n)-[r]-(m) RETURN n, r, m"
        result = session.run(query)
        # Creare liste per nodi e archi
        nodes = {}
        edges = []
        relation_texts = []

        phase_already_taken = []

        for record in result:
            relation_dict = {}
            relation = {}
            phase_index = -1
            document_name = ""

            # Itera su tutti gli elementi nel record
            for value in record.values():

                # Gestisce i nodi
                if hasattr(value, 'labels'):
                    node_id = value.id  # ID univoco del nodo
                    if node_id not in nodes:
                        labels = [l for l in value.labels if l!="Node"]
                        node_text = value['text']
                        map=[]
                        for l in labels:
                            new_mapping={}
                            if l in labels_mapping:
                                new_mapping['categoria_id']=labels_mapping[l]['id']
                                for key in labels_mapping[l]['labels']:
                                    if key in node_text:
                                        new_mapping["\"entita_id\""]=labels_mapping[l]['labels'][key]
                                        break
                            map.append(new_mapping)

                        nodes[node_id] = {
                            'id': node_id,
                            'labels': map,
                            'properties': dict(value)
                        }

                # Gestisce le relazioni
                elif hasattr(value, 'type'):
                    # Ottiene gli ID dei nodi di origine e destinazione
                    start_node = value.start_node
                    end_node = value.end_node

                    relation['subject'] = start_node['text']
                    if (relation['subject'] != end_node['text']):
                        relation['object'] = end_node['text']

                    # Aggiunge i nodi se non esistono già
                    if start_node.id not in nodes:
                        labels_start_node = [l for l in start_node.labels if l!="Node"]
                        node_text = start_node['text']
                        map=[]
                        for l in labels_start_node:
                            new_mapping={}
                            if l in labels_mapping:
                                new_mapping['categoria_id']=labels_mapping[l]['id']
                                for key in labels_mapping[l]['labels']:
                                    if key in node_text:
                                        new_mapping["\"entita_id\""]=labels_mapping[l]['labels'][key]
                                        break
                            map.append(new_mapping)

                        nodes[start_node.id] = {
                            'id': start_node.id,
                            'labels': map,
                            'properties': dict(start_node)
                        }

                    if end_node.id not in nodes:
                        labels_end_node= [l for l in end_node.labels if l!="Node"]
                        node_text = end_node['text']
                        map=[]
                        for l in labels_end_node:
                            new_mapping={}
                            if l in labels_mapping:
                                new_mapping['categoria_id']=labels_mapping[l]['id']
                                for key in labels_mapping[l]['labels']:
                                    if key in node_text:
                                        new_mapping["\"entita_id\""]=labels_mapping[l]['labels'][key]
                                        break
                            map.append(new_mapping)
                        nodes[end_node.id] = {
                            'id': end_node.id,
                            'labels': map,
                            'properties': dict(end_node)
                        }


                    new_value_dict = {}
                    for key in value:
                        if key == 'documentName':
                            document_name = value[key]
                        elif key == 'sentencesIndex':
                            phase_index = value[key]
                        else:
                            new_value_dict[key] = value[key]

                    # Crea l'arco
                    edge = {
                        'id': value.id,
                        'source': start_node.id,
                        'target': end_node.id,
                        'type': value.type,
                        'properties': dict(new_value_dict)
                    }
                    edges.append(edge)

                    relation['verb'] = value.type
                    relation['properties'] = dict(value)

            relation_dict['relation'] = relation
            #Get the relation text
            if document_name != "" and phase_index != -1:
                if phase_index in phase_already_taken:
                    relation_dict['text'] = ""
                else:

                    phase_already_taken.append(phase_index)

            relation_texts.append(relation_dict)

        # Restituire i nodi e gli archi come liste
        return {
            "nodes": list(nodes.values()),
            "edges": edges,
            'relation_texts': relation_texts
        }

    except Exception as e:
        print(f"Errore durante l'esecuzione della query: {e}")
        return None

def extract_graph_data(session,labels_mapping):

    result = execute_query(session,labels_mapping)

    if not result:
        return None

    graph_data = []

    for edge in result['edges']:
        node1_id = edge['source']
        node2_id = edge['target']

        node1 = next(node for node in result['nodes'] if node['id'] == node1_id)
        node2 = next(node for node in result['nodes'] if node['id'] == node2_id)

        graph_data.append({
            "nodo1": {
                "id": node1['id'],
                "labels": node1['labels']
            },
            "nodo2": {
                "id": node2['id'],
                "labels": node2['labels']
            },
            "arco": {
                "id": edge['id']
            }
        })

    return graph_data

# %%
from neo4j import GraphDatabase

import warnings

warnings.simplefilter("ignore", DeprecationWarning)


uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "14052001"))
session = driver.session(database= "cleanedgraph2")

graph_data = extract_graph_data(session,labels_mapping)

# %%
graph_data
# Out:
# [{'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152921504606846976}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 1, 'labels': [{'categoria_id': 2, '"entita_id"': 1}]},
#   'arco': {'id': 1152922604118474752}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 1, 'labels': [{'categoria_id': 2, '"entita_id"': 1}]},
#   'arco': {'id': 1152922604118474752}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'arco': {'id': 1152932499723124736}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'arco': {'id': 1152932499723124736}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'arco': {'id': 1152933599234752512}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'arco': {'id': 1152933599234752512}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1152995171885907968}},
#  {'nodo1': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1152995171885907968}},
#  {'nodo1': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'arco': {'id': 1152923703630102530}},
#  {'nodo1': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'nodo2': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'arco': {'id': 1152923703630102530}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 39, 'labels': [{'categoria_id': 2, '"entita_id"': 2437}]},
#   'arco': {'id': 6917591699803865127}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 39, 'labels': [{'categoria_id': 2, '"entita_id"': 2437}]},
#   'arco': {'id': 6917591699803865127}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 100, 'labels': [{'categoria_id': 20, '"entita_id"': 1385}]},
#   'arco': {'id': 1153137008885891075}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 100, 'labels': [{'categoria_id': 20, '"entita_id"': 1385}]},
#   'arco': {'id': 1153137008885891075}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 126, 'labels': [{'categoria_id': 22, '"entita_id"': 388}]},
#   'arco': {'id': 6917769820687564926}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 126, 'labels': [{'categoria_id': 22, '"entita_id"': 388}]},
#   'arco': {'id': 6917769820687564926}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 2320, 'labels': [{'categoria_id': 2, '"entita_id"': 2229}]},
#   'arco': {'id': 8070684041029880080}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 2320, 'labels': [{'categoria_id': 2, '"entita_id"': 2229}]},
#   'arco': {'id': 8070684041029880080}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 2306109194106830851}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 2306109194106830851}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306109228466569219}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306109228466569219}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306109262826307587}},
#  {'nodo1': {'id': 3, 'labels': [{'categoria_id': 5, '"entita_id"': 3238}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306109262826307587}},
#  {'nodo1': {'id': 4, 'labels': [{'categoria_id': 6, '"entita_id"': 395}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1152924803141730308}},
#  {'nodo1': {'id': 4, 'labels': [{'categoria_id': 6, '"entita_id"': 395}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1152924803141730308}},
#  {'nodo1': {'id': 4, 'labels': [{'categoria_id': 6, '"entita_id"': 395}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152925902653358084}},
#  {'nodo1': {'id': 4, 'labels': [{'categoria_id': 6, '"entita_id"': 395}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152925902653358084}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 200, 'labels': [{'categoria_id': 1, '"entita_id"': 8653}]},
#   'arco': {'id': 2305976565516730373}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 200, 'labels': [{'categoria_id': 1, '"entita_id"': 8653}]},
#   'arco': {'id': 2305976565516730373}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1388, 'labels': [{'categoria_id': 32, '"entita_id"': 140}]},
#   'arco': {'id': 8070587455805326700}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1388, 'labels': [{'categoria_id': 32, '"entita_id"': 140}]},
#   'arco': {'id': 8070587455805326700}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306003400472395781}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306003400472395781}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2012, 'labels': [{'categoria_id': 16}]},
#   'arco': {'id': 8070651571077122012}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2012, 'labels': [{'categoria_id': 16}]},
#   'arco': {'id': 8070651571077122012}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2049, 'labels': [{'categoria_id': 22, '"entita_id"': 295}]},
#   'arco': {'id': 2306047380937506821}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2049, 'labels': [{'categoria_id': 22, '"entita_id"': 295}]},
#   'arco': {'id': 2306047380937506821}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306129569431683077}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306129569431683077}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306136578818310149}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306136578818310149}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306141526620635141}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306141526620635141}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 20, 'labels': [{'categoria_id': 4, '"entita_id"': 184}]},
#   'arco': {'id': 2306141938937495557}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 20, 'labels': [{'categoria_id': 4, '"entita_id"': 184}]},
#   'arco': {'id': 2306141938937495557}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306150631951302661}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 2306150631951302661}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2306164856882987013}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2306164856882987013}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152927002164985861}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152927002164985861}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152928101676613637}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1152928101676613637}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152937997281263621}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152937997281263621}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 6917554316408520723}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 6917554316408520723}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 32, 'labels': [{'categoria_id': 20, '"entita_id"': 1504}]},
#   'arco': {'id': 1152964385560330245}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 32, 'labels': [{'categoria_id': 20, '"entita_id"': 1504}]},
#   'arco': {'id': 1152964385560330245}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 30, 'labels': [{'categoria_id': 1, '"entita_id"': 8566}]},
#   'arco': {'id': 1152967684095213573}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 30, 'labels': [{'categoria_id': 1, '"entita_id"': 8566}]},
#   'arco': {'id': 1152967684095213573}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152979778723119109}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152979778723119109}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 29, 'labels': [{'categoria_id': 20, '"entita_id"': 1384}]},
#   'arco': {'id': 1152980878234746885}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 29, 'labels': [{'categoria_id': 20, '"entita_id"': 1384}]},
#   'arco': {'id': 1152980878234746885}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152996271397535749}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 1152996271397535749}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 6917604893943398445}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 6917604893943398445}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2305915645700603909}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2305915645700603909}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2305915714420080645}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 2305915714420080645}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305916264175894533}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305916264175894533}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153022659676602373}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153022659676602373}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153027057723113477}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153027057723113477}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 675, 'labels': [{'categoria_id': 7, '"entita_id"': 6378}]},
#   'arco': {'id': 8070735649356907171}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 675, 'labels': [{'categoria_id': 7, '"entita_id"': 6378}]},
#   'arco': {'id': 8070735649356907171}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 8070735683716644920}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 8070735683716644920}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 73, 'labels': [{'categoria_id': 2, '"entita_id"': 2250}]},
#   'arco': {'id': 6917669765129437257}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 73, 'labels': [{'categoria_id': 2, '"entita_id"': 2250}]},
#   'arco': {'id': 6917669765129437257}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070736439630889300}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070736439630889300}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 42, 'labels': [{'categoria_id': 3, '"entita_id"': 634}]},
#   'arco': {'id': 2306129054035607557}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 42, 'labels': [{'categoria_id': 3, '"entita_id"': 634}]},
#   'arco': {'id': 2306129054035607557}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 1153072137699852293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 1153072137699852293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 74, 'labels': [{'categoria_id': 7, '"entita_id"': 6367}]},
#   'arco': {'id': 1153073237211480069}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 74, 'labels': [{'categoria_id': 7, '"entita_id"': 6367}]},
#   'arco': {'id': 1153073237211480069}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 77, 'labels': [{'categoria_id': 17, '"entita_id"': 735}]},
#   'arco': {'id': 6917681859757342797}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 77, 'labels': [{'categoria_id': 17, '"entita_id"': 735}]},
#   'arco': {'id': 6917681859757342797}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 78, 'labels': [{'categoria_id': 7, '"entita_id"': 3926}]},
#   'arco': {'id': 6917682959268970574}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 78, 'labels': [{'categoria_id': 7, '"entita_id"': 3926}]},
#   'arco': {'id': 6917682959268970574}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 384, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306059613004365829}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 384, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306059613004365829}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 457, 'labels': [{'categoria_id': 14, '"entita_id"': 2026}]},
#   'arco': {'id': 2306059647364104197}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 457, 'labels': [{'categoria_id': 14, '"entita_id"': 2026}]},
#   'arco': {'id': 2306059647364104197}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 149, 'labels': [{'categoria_id': 14, '"entita_id"': 2031}]},
#   'arco': {'id': 2306059681723842565}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 149, 'labels': [{'categoria_id': 14, '"entita_id"': 2031}]},
#   'arco': {'id': 2306059681723842565}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 8070667239117815853}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 8070667239117815853}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 96, 'labels': [{'categoria_id': 4, '"entita_id"': 110}]},
#   'arco': {'id': 6917715944617803872}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 96, 'labels': [{'categoria_id': 4, '"entita_id"': 110}]},
#   'arco': {'id': 6917715944617803872}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2170, 'labels': [{'categoria_id': 26, '"entita_id"': 199}]},
#   'arco': {'id': 8070667617074940026}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2170, 'labels': [{'categoria_id': 26, '"entita_id"': 199}]},
#   'arco': {'id': 8070667617074940026}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2169, 'labels': [{'categoria_id': 2, '"entita_id"': 2251}]},
#   'arco': {'id': 8070667582715201657}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2169, 'labels': [{'categoria_id': 2, '"entita_id"': 2251}]},
#   'arco': {'id': 8070667582715201657}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306060162760179717}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2306060162760179717}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2170, 'labels': [{'categoria_id': 26, '"entita_id"': 199}]},
#   'arco': {'id': 8070667720154155130}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2170, 'labels': [{'categoria_id': 26, '"entita_id"': 199}]},
#   'arco': {'id': 8070667720154155130}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 138, 'labels': [{'categoria_id': 7, '"entita_id"': 6130}]},
#   'arco': {'id': 8070738947891789962}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 138, 'labels': [{'categoria_id': 7, '"entita_id"': 6130}]},
#   'arco': {'id': 8070738947891789962}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 20}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070739222769697108}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070739222769697108}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070739360208650580}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070739360208650580}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 21}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 21}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2548, 'labels': [{'categoria_id': 35, '"entita_id"': 774}]},
#   'arco': {'id': 8070739566367082996}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2548, 'labels': [{'categoria_id': 35, '"entita_id"': 774}]},
#   'arco': {'id': 8070739566367082996}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 93, 'labels': [{'categoria_id': 1, '"entita_id"': 8792}]},
#   'arco': {'id': 8070739772525510749}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 93, 'labels': [{'categoria_id': 1, '"entita_id"': 8792}]},
#   'arco': {'id': 8070739772525510749}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 32, 'labels': [{'categoria_id': 20, '"entita_id"': 1504}]},
#   'arco': {'id': 1153172193257979909}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 32, 'labels': [{'categoria_id': 20, '"entita_id"': 1504}]},
#   'arco': {'id': 1153172193257979909}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2549, 'labels': [{'categoria_id': 38, '"entita_id"': 435}]},
#   'arco': {'id': 8070739806885251573}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2549, 'labels': [{'categoria_id': 38, '"entita_id"': 435}]},
#   'arco': {'id': 8070739806885251573}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 130, 'labels': [{'categoria_id': 7, '"entita_id"': 6174}]},
#   'arco': {'id': 6917784114338726018}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 130, 'labels': [{'categoria_id': 7, '"entita_id"': 6174}]},
#   'arco': {'id': 6917784114338726018}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153177690816118789}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153177690816118789}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 131, 'labels': [{'categoria_id': 7, '"entita_id"': 6183}]},
#   'arco': {'id': 6917790711408492675}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 131, 'labels': [{'categoria_id': 7, '"entita_id"': 6183}]},
#   'arco': {'id': 6917790711408492675}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153184287885885445}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153184287885885445}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 131, 'labels': [{'categoria_id': 7, '"entita_id"': 6183}]},
#   'arco': {'id': 1153194183490535429}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 131, 'labels': [{'categoria_id': 7, '"entita_id"': 6183}]},
#   'arco': {'id': 1153194183490535429}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 138, 'labels': [{'categoria_id': 7, '"entita_id"': 6130}]},
#   'arco': {'id': 6917807204082909322}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 138, 'labels': [{'categoria_id': 7, '"entita_id"': 6130}]},
#   'arco': {'id': 6917807204082909322}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 139, 'labels': [{'categoria_id': 7, '"entita_id"': 5689}]},
#   'arco': {'id': 1153238163955646469}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 139, 'labels': [{'categoria_id': 7, '"entita_id"': 5689}]},
#   'arco': {'id': 1153238163955646469}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070742074627981652}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070742074627981652}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070744445449929044}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070744445449929044}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 457, 'labels': [{'categoria_id': 14, '"entita_id"': 2026}]},
#   'arco': {'id': 8070675348016071113}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 457, 'labels': [{'categoria_id': 14, '"entita_id"': 2026}]},
#   'arco': {'id': 8070675348016071113}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 149, 'labels': [{'categoria_id': 14, '"entita_id"': 2031}]},
#   'arco': {'id': 8070675382375809173}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 149, 'labels': [{'categoria_id': 14, '"entita_id"': 2031}]},
#   'arco': {'id': 8070675382375809173}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 8070675416735547437}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 8070675416735547437}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070675691613454676}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070675691613454676}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 187, 'labels': [{'categoria_id': 14, '"entita_id"': 2032}]},
#   'arco': {'id': 8070675725973192891}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 187, 'labels': [{'categoria_id': 14, '"entita_id"': 2032}]},
#   'arco': {'id': 8070675725973192891}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 2306068237298696197}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 2306068237298696197}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306069611688230917}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306069611688230917}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 20, 'labels': [{'categoria_id': 4, '"entita_id"': 184}]},
#   'arco': {'id': 8070749255813300244}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 20, 'labels': [{'categoria_id': 4, '"entita_id"': 184}]},
#   'arco': {'id': 8070749255813300244}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2374, 'labels': [{'categoria_id': 40, '"entita_id"': 146}]},
#   'arco': {'id': 8070749290173040966}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2374, 'labels': [{'categoria_id': 40, '"entita_id"': 146}]},
#   'arco': {'id': 8070749290173040966}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 8070749324532776979}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 8070749324532776979}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2374, 'labels': [{'categoria_id': 40, '"entita_id"': 146}]},
#   'arco': {'id': 8070749496331471174}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2374, 'labels': [{'categoria_id': 40, '"entita_id"': 146}]},
#   'arco': {'id': 8070749496331471174}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 177, 'labels': [{'categoria_id': 7, '"entita_id"': 6379}]},
#   'arco': {'id': 8070749530691207345}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 177, 'labels': [{'categoria_id': 7, '"entita_id"': 6379}]},
#   'arco': {'id': 8070749530691207345}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 716, 'labels': [{'categoria_id': 50}]},
#   'arco': {'id': 8070750870721004236}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 716, 'labels': [{'categoria_id': 50}]},
#   'arco': {'id': 8070750870721004236}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1724, 'labels': [{'categoria_id': 4, '"entita_id"': 106}]},
#   'arco': {'id': 8070612916371457724}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1724, 'labels': [{'categoria_id': 4, '"entita_id"': 106}]},
#   'arco': {'id': 8070612916371457724}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306005427696959493}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306005427696959493}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305935849226764293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305935849226764293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 8070685552858365971}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 19, 'labels': [{'categoria_id': 2, '"entita_id"': 2526}]},
#   'arco': {'id': 8070685552858365971}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2305942308857577477}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2305942308857577477}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2305942411936792581}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2305942411936792581}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 38, 'labels': [{'categoria_id': 27}]},
#   'arco': {'id': 2306013021199138821}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 38, 'labels': [{'categoria_id': 27}]},
#   'arco': {'id': 2306013021199138821}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 36, 'labels': [{'categoria_id': 5, '"entita_id"': 3294}]},
#   'arco': {'id': 2306016319734022149}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 36, 'labels': [{'categoria_id': 5, '"entita_id"': 3294}]},
#   'arco': {'id': 2306016319734022149}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 18, 'labels': [{'categoria_id': 7, '"entita_id"': 5850}]},
#   'arco': {'id': 8070623877127995410}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 18, 'labels': [{'categoria_id': 7, '"entita_id"': 5850}]},
#   'arco': {'id': 8070623877127995410}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1210, 'labels': [{'categoria_id': 12, '"entita_id"': 281}]},
#   'arco': {'id': 8070623980207211706}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1210, 'labels': [{'categoria_id': 12, '"entita_id"': 281}]},
#   'arco': {'id': 8070623980207211706}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 22, 'labels': [{'categoria_id': 2, '"entita_id"': 2445}]},
#   'arco': {'id': 2306016628971667461}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 22, 'labels': [{'categoria_id': 2, '"entita_id"': 2445}]},
#   'arco': {'id': 2306016628971667461}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 8070695001786417822}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 8070695001786417822}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 17, 'labels': [{'categoria_id': 7, '"entita_id"': 6064}]},
#   'arco': {'id': 1154002324536950789}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 17, 'labels': [{'categoria_id': 7, '"entita_id"': 6064}]},
#   'arco': {'id': 1154002324536950789}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 384, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 1154052902071828485}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 384, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 1154052902071828485}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 120, 'labels': [{'categoria_id': 7, '"entita_id"': 4607}]},
#   'arco': {'id': 2306019137232568325}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 120, 'labels': [{'categoria_id': 7, '"entita_id"': 4607}]},
#   'arco': {'id': 2306019137232568325}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1810, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 8070626694626543378}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1810, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 8070626694626543378}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 120, 'labels': [{'categoria_id': 7, '"entita_id"': 4607}]},
#   'arco': {'id': 2306019240311783429}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 120, 'labels': [{'categoria_id': 7, '"entita_id"': 4607}]},
#   'arco': {'id': 2306019240311783429}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1811, 'labels': [{'categoria_id': 49, '"entita_id"': 215}]},
#   'arco': {'id': 8070626797705758483}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1811, 'labels': [{'categoria_id': 49, '"entita_id"': 215}]},
#   'arco': {'id': 8070626797705758483}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 143, 'labels': [{'categoria_id': 7, '"entita_id"': 6105}]},
#   'arco': {'id': 2306020511622103045}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 143, 'labels': [{'categoria_id': 7, '"entita_id"': 6105}]},
#   'arco': {'id': 2306020511622103045}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 152, 'labels': [{'categoria_id': 7, '"entita_id"': 6106}]},
#   'arco': {'id': 2306020545981841413}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 152, 'labels': [{'categoria_id': 7, '"entita_id"': 6106}]},
#   'arco': {'id': 2306020545981841413}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 648, 'labels': [{'categoria_id': 7, '"entita_id"': 3880}]},
#   'arco': {'id': 2306020580341579781}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 648, 'labels': [{'categoria_id': 7, '"entita_id"': 3880}]},
#   'arco': {'id': 2306020580341579781}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 8070559521338032798}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 8070559521338032798}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070773273270419796}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 340, 'labels': [{'categoria_id': 28, '"entita_id"': 837}]},
#   'arco': {'id': 8070773273270419796}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 754, 'labels': [{'categoria_id': 10, '"entita_id"': 693}]},
#   'arco': {'id': 8070633051178140402}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 754, 'labels': [{'categoria_id': 10, '"entita_id"': 693}]},
#   'arco': {'id': 8070633051178140402}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 36, 'labels': [{'categoria_id': 5, '"entita_id"': 3294}]},
#   'arco': {'id': 2306026799454224389}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 36, 'labels': [{'categoria_id': 5, '"entita_id"': 3294}]},
#   'arco': {'id': 2306026799454224389}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306026833813962757}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 2306026833813962757}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 8070776193848180761}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 8070776193848180761}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 14, 'labels': [{'categoria_id': 20, '"entita_id"': 1496}]},
#   'arco': {'id': 8070706546658508814}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 14, 'labels': [{'categoria_id': 20, '"entita_id"': 1496}]},
#   'arco': {'id': 8070706546658508814}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306099057984012293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306099057984012293}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 8070706649737723929}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 25, 'labels': [{'categoria_id': 7, '"entita_id"': 6358}]},
#   'arco': {'id': 8070706649737723929}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 10}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 10}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 11}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 7, 'labels': [{'categoria_id': 7, '"entita_id"': 6344}]},
#   'arco': {'id': 11}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306099264142442501}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306099264142442501}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305959076409901061}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 670, 'labels': [{'categoria_id': 28}]},
#   'arco': {'id': 2305959076409901061}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 24, 'labels': [{'categoria_id': 7, '"entita_id"': 6370}]},
#   'arco': {'id': 8070637827181772824}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 24, 'labels': [{'categoria_id': 7, '"entita_id"': 6370}]},
#   'arco': {'id': 8070637827181772824}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2385, 'labels': [{'categoria_id': 10, '"entita_id"': 837}]},
#   'arco': {'id': 8070709948272609617}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 2385, 'labels': [{'categoria_id': 10, '"entita_id"': 837}]},
#   'arco': {'id': 8070709948272609617}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'nodo2': {'id': 1898, 'labels': [{'categoria_id': 2}]},
#   'arco': {'id': 8070639648247908202}},
#  {'nodo1': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
# ...
#   'arco': {'id': 1153231566885879816}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 153, 'labels': [{'categoria_id': 7, '"entita_id"': 6107}]},
#   'arco': {'id': 1153232666397507592}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 153, 'labels': [{'categoria_id': 7, '"entita_id"': 6107}]},
#   'arco': {'id': 1153232666397507592}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 6917847886013136952}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 56, 'labels': [{'categoria_id': 11, '"entita_id"': 1372}]},
#   'arco': {'id': 6917847886013136952}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306004671782715400}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306004671782715400}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 109, 'labels': [{'categoria_id': 20, '"entita_id"': 1416}]},
#   'arco': {'id': 2306012780680970248}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 109, 'labels': [{'categoria_id': 20, '"entita_id"': 1416}]},
#   'arco': {'id': 2306012780680970248}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1771, 'labels': [{'categoria_id': 11, '"entita_id"': 174}]},
#   'arco': {'id': 8070620372434683627}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1771, 'labels': [{'categoria_id': 11, '"entita_id"': 174}]},
#   'arco': {'id': 8070620372434683627}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306012883760185352}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306012883760185352}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306012952479662088}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306012952479662088}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 38, 'labels': [{'categoria_id': 27}]},
#   'arco': {'id': 2306012986839400456}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 38, 'labels': [{'categoria_id': 27}]},
#   'arco': {'id': 2306012986839400456}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306014155070504968}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306014155070504968}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 216, 'labels': [{'categoria_id': 7, '"entita_id"': 6359}]},
#   'arco': {'id': 2306014773545795592}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 216, 'labels': [{'categoria_id': 7, '"entita_id"': 6359}]},
#   'arco': {'id': 2306014773545795592}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306014807905533960}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306014807905533960}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 203, 'labels': [{'categoria_id': 7, '"entita_id"': 6099}]},
#   'arco': {'id': 2306014876625010696}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 203, 'labels': [{'categoria_id': 7, '"entita_id"': 6099}]},
#   'arco': {'id': 2306014876625010696}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 2306014910984749064}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 45, 'labels': [{'categoria_id': 1, '"entita_id"': 8757}]},
#   'arco': {'id': 2306014910984749064}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1729, 'labels': [{'categoria_id': 12, '"entita_id"': 383}]},
#   'arco': {'id': 2306015151502917640}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1729, 'labels': [{'categoria_id': 12, '"entita_id"': 383}]},
#   'arco': {'id': 2306015151502917640}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2306015185862656008}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 80, 'labels': [{'categoria_id': 7, '"entita_id"': 6366}]},
#   'arco': {'id': 2306015185862656008}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016147935330312}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016147935330312}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016491532713992}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016491532713992}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1790, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 8070624048926689022}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1790, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 8070624048926689022}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016560252190728}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016560252190728}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 22, 'labels': [{'categoria_id': 2, '"entita_id"': 2445}]},
#   'arco': {'id': 2306016594611929096}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 22, 'labels': [{'categoria_id': 2, '"entita_id"': 2445}]},
#   'arco': {'id': 2306016594611929096}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 433, 'labels': [{'categoria_id': 12, '"entita_id"': 381}]},
#   'arco': {'id': 8070624220725379505}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 433, 'labels': [{'categoria_id': 12, '"entita_id"': 381}]},
#   'arco': {'id': 8070624220725379505}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016766410620936}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306016766410620936}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 109, 'labels': [{'categoria_id': 20, '"entita_id"': 1416}]},
#   'arco': {'id': 2306017934641725448}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 109, 'labels': [{'categoria_id': 20, '"entita_id"': 1416}]},
#   'arco': {'id': 2306017934641725448}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306019102872829960}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306019102872829960}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306019377750736904}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 37, 'labels': [{'categoria_id': 1, '"entita_id"': 8783}]},
#   'arco': {'id': 2306019377750736904}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306019412110475272}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306019412110475272}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1833, 'labels': [{'categoria_id': 10, '"entita_id"': 407}]},
#   'arco': {'id': 8070629787002996521}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 1833, 'labels': [{'categoria_id': 10, '"entita_id"': 407}]},
#   'arco': {'id': 8070629787002996521}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 6, 'labels': [{'categoria_id': 5, '"entita_id"': 3330}]},
#   'arco': {'id': 2306028723599573000}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 6, 'labels': [{'categoria_id': 5, '"entita_id"': 3330}]},
#   'arco': {'id': 2306028723599573000}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 136, 'labels': [{'categoria_id': 20, '"entita_id"': 1502}]},
#   'arco': {'id': 2306033190365560840}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 136, 'labels': [{'categoria_id': 20, '"entita_id"': 1502}]},
#   'arco': {'id': 2306033190365560840}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 14, 'labels': [{'categoria_id': 20, '"entita_id"': 1496}]},
#   'arco': {'id': 2306033637042159624}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 14, 'labels': [{'categoria_id': 20, '"entita_id"': 1496}]},
#   'arco': {'id': 2306033637042159624}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306033671401897992}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 2306033671401897992}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 177, 'labels': [{'categoria_id': 7, '"entita_id"': 6379}]},
#   'arco': {'id': 2306033877560328200}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 177, 'labels': [{'categoria_id': 7, '"entita_id"': 6379}]},
#   'arco': {'id': 2306033877560328200}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 13, 'labels': [{'categoria_id': 17, '"entita_id"': 743}]},
#   'arco': {'id': 6917548818850381837}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 13, 'labels': [{'categoria_id': 17, '"entita_id"': 743}]},
#   'arco': {'id': 6917548818850381837}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153153501560307720}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 0, 'labels': [{'categoria_id': 2, '"entita_id"': 85}]},
#   'arco': {'id': 1153153501560307720}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153014963095207944}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153014963095207944}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 119, 'labels': [{'categoria_id': 7, '"entita_id"': 6256}]},
#   'arco': {'id': 6917762124106170487}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 119, 'labels': [{'categoria_id': 7, '"entita_id"': 6256}]},
#   'arco': {'id': 6917762124106170487}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 6917625784664326199}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 6917625784664326199}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153024858699857928}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153024858699857928}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153025958211485704}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 55, 'labels': [{'categoria_id': 2, '"entita_id"': 2479}]},
#   'arco': {'id': 1153025958211485704}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 24, 'labels': [{'categoria_id': 7, '"entita_id"': 6370}]},
#   'arco': {'id': 1153098525978918920}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 24, 'labels': [{'categoria_id': 7, '"entita_id"': 6370}]},
#   'arco': {'id': 1153098525978918920}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153099625490546696}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153099625490546696}},
#  {'nodo1': {'id': 8, 'labels': [{'categoria_id': 6, '"entita_id"': 588}]},
#   'nodo2': {'id': 5, 'labels': [{'categoria_id': 1, '"entita_id"': 8789}]},
#   'arco': {'id': 1153109521095196680}},
#  ...]

# %%
#Save the graph data in a json file
with open('graph_data.json', 'w') as f:
    json.dump(graph_data, f)

# %% [markdown]
# Mapping tra node_id e text in modo da poter prendere il testo dati gli id

# %%
from neo4j import GraphDatabase

uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "14052001"))
session = driver.session(database= "cleanedgraph2")

def get_nodes_dict(session):
    query = "MATCH (n) RETURN id(n) AS id, n.text AS text"
    result = session.run(query)
    return {record["id"]: record["text"] for record in result}

node_dict= get_nodes_dict(session)


#Save as json with node_id_text.json
with open('Project/GraphAnalysis/energyReportsGraph/node_id_text.json', 'w') as f:
    json.dump(node_dict, f)
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 1, column: 18, offset: 17} for query: 'MATCH (n) RETURN id(n) AS id, n.text AS text'
# {0: 'NDC',
#  1: 'Party',
#  2: 'NDCs',
#  3: 'renewable energy',
#  4: 'renewable electricity capacity',
#  5: '2030',
#  6: 'solar pv',
#  7: 'China',
#  8: 'renewable capacity',
#  9: 'wind energy',
#  10: 'policy stocktaking',
#  11: 'IEA',
#  12: 'renewable capacity ambitions',
#  13: 'European',
#  14: 'Europe',
#  15: 'Spain',
#  16: 'Italy',
#  17: 'France',
#  18: 'United Kingdom',
#  19: 'European Union',
#  20: 'climate goals',
#  21: 'NECP',
#  22: 'European Commission',
#  23: 'Asia Pacific region',
#  24: 'India',
#  25: 'Japan',
#  26: 'fossil fuel capacity',
#  27: 'electricity generation share',
#  28: 'renewable energy capacity',
#  29: 'Latin America',
#  30: '2022',
#  31: 'Sub Saharan Africa',
#  32: 'Eurasia',
#  33: 'renewable energy capacity ambitions',
#  34: 'MENA',
#  35: 'hydropower',
#  36: 'wind',
#  37: '2023',
#  38: 'cop28',
#  39: 'IEA Emissions 2050',
#  40: 'EMDEs',
#  41: 'global greenhouse gas emissions',
#  42: 'emissions',
#  43: 'co2 emissions',
#  44: 'solar power capacity',
#  45: '2024',
#  46: 'generation costs',
#  47: 'generation costs coal',
#  48: 'wind installations',
#  49: 'hydropower capacity',
#  50: 'bioenergy capacity',
#  51: 'global ghg emissions',
#  52: 'heat production',
#  53: 'solar',
#  54: 'renewable energy technology',
#  55: 'EU',
#  56: 'economies',
#  57: 'Ukraine',
#  58: 'Russia',
#  59: 'REPowerEU',
#  60: 'Germany',
#  61: 'Netherlands',
#  62: 'Denmark',
#  63: 'Poland',
#  64: 'Belgium',
#  65: 'Ireland',
#  66: 'Sweden',
#  67: 'wind aspirations',
#  68: 'Portugal',
#  69: 'geothermal',
#  70: 'Croatia',
#  71: 'Slovakia',
#  72: 'ocean technologies',
#  73: 'ASEAN',
#  74: 'Viet Nam',
#  75: 'wind power',
#  76: 'Power Development Plan',
#  77: 'Chinese',
#  78: 'Taipei',
#  79: 'bioenergy capacity deployment',
#  80: 'Indonesia',
#  81: 'Philippines',
#  82: 'New Zealand',
#  83: 'power supply',
#  84: 'cost pv',
#  85: 'wind technologies',
#  86: 'fuel import dependency',
#  87: 'ghg emissions',
#  88: 'fossil fuel',
#  89: 'Thailand',
#  90: 'Malaysia',
#  91: 'renewable energy market',
#  92: 'vre capacity',
#  93: '2035',
#  94: 'US',
#  95: 'electricity generation',
#  96: 'emissions reduction plan',
#  97: 'nuclear',
#  98: 'Canada',
#  99: 'incentives',
#  100: 'Caribbean',
#  101: 'global ghg emissions heat production',
#  102: 'Brazil',
#  103: 'Mexico',
#  104: 'Chile',
#  105: 'wind capacity',
#  106: 'climate change consequences',
#  107: 'global emissions',
#  108: 'climate change impacts',
#  109: 'sub Saharan Africa',
#  110: 'electricity access',
#  111: 'policy ambitions',
#  112: 'fuel oil generators',
#  113: 'renewable energy installations',
#  114: 'geothermal capacity',
#  115: 'Eritrea',
#  116: 'Ethiopia',
#  117: 'Kenya',
#  118: 'Tanzania',
#  119: 'South Africa',
#  120: 'Angola',
#  121: 'Benin',
#  122: 'Côte d’Ivoire',
#  123: 'Gabon',
#  124: 'Rwanda',
#  125: 'Senegal',
#  126: 'fuel switching',
#  127: 'fossil fuel fired generation',
#  128: 'wind power plants',
#  129: 'renewable capacity ambition',
#  130: 'Azerbaijan',
#  131: 'Uzbekistan',
#  132: 'Eurasia electricity generation',
#  133: 'Eurasian',
#  134: 'solar pv capacity',
#  135: 'fossil fuels',
#  136: 'Middle East',
#  137: 'North Africa',
#  138: 'Saudi Arabia',
#  139: 'Egypt',
#  140: 'National Energy Plan',
#  141: '2016',
#  142: 'natural gas',
#  143: 'United Arab Emirates',
#  144: 'power demand',
#  145: 'Jordan',
#  146: 'Iraq',
#  147: 'Tunisia',
#  148: 'Kuwait',
#  149: 'gas',
#  150: 'Libya',
#  151: 'Qatar',
#  152: 'Oman',
#  153: 'Bahrain',
#  154: 'Iran',
#  155: 'loan guarantees',
#  156: 'market price signals',
#  157: 'renewable energy generators',
#  158: 'power sector decarbonisation goals',
#  159: 'renewable electricity technologies',
#  160: 'fossil fuel alternatives',
#  161: 'battery systems',
#  162: 'hydropower projects',
#  163: 'Southeast Asia',
#  164: 'energy',
#  165: 'electricity consumption',
#  166: 'data centres',
#  167: 'cryptocurrency sector',
#  168: '2026',
#  169: 'electricity demand growth',
#  170: 'solar pv modules',
#  171: 'electric vehicles',
#  172: 'global electricity demand growth',
#  173: 'Africa',
#  174: 'electricity supply',
#  175: 'total electricity demand',
#  176: '2024 to 2026',
#  177: 'United States',
#  178: 'European Union ’s',
#  179: 'electricity prices',
#  180: 'electricity costs',
#  181: 'Russia Ukraine',
#  182: 'new',
#  183: 'policy initiatives',
#  184: 'policy makers',
#  185: 'low emissions sources',
#  186: 'power sector',
#  187: 'coal',
#  188: 'hydropower output',
#  189: 'power',
#  190: '2025',
#  191: 'Asia',
#  192: '2014',
#  193: 'global co2 emissions',
#  194: 'co2 emissions',
#  195: 'government policies',
#  196: 'emissions individual years',
#  197: 'fired',
#  198: 'emissions intensity',
#  199: 'wholesale electricity prices',
#  200: '2019',
#  201: 'higher futures prices',
#  202: 'Nordics',
#  203: 'Australia',
#  204: 'hydropower generation',
#  205: 'fuel supply challenges',
#  206: 'global electricity demand',
#  207: 'emerging markets',
#  208: 'energy crisis',
#  209: 'inflation levels',
#  210: 'debt burdens',
#  211: 'energy data centres',
#  212: 'gdp growth rate',
#  213: '2025 2026',
#  214: 'IMF',
#  215: 'glass',
#  216: 'Korea',
#  217: 'us electricity demand',
#  218: 'manufacturing sector',
#  219: '1990',
#  220: '1995',
#  221: '2008',
#  222: '2010',
#  223: '2015',
#  224: 'renewable generation',
#  225: 'Ghana',
#  226: '2015 2019',
#  227: 'eu electricity demand',
#  228: '2021',
#  229: 'gdp growth',
#  230: 'data centre electricity demand',
#  231: 'electricity price',
#  232: 'electricity demand destruction',
#  233: 'soda',
#  234: 'Ludwigshafen',
#  235: 'electricity demand reductions',
#  236: 'companies',
#  237: 'Slovalco',
#  238: 'Speira',
#  239: 'Rheinwerk',
#  240: 'Talum',
#  241: 'aluminium production',
#  242: 'Liberty Aluminium',
#  243: 'Dunkirk',
#  244: 'Alcoa',
#  245: 'San Ciprian',
#  246: 'energy costs',
#  247: 'Real Alloy Europe',
#  248: 'aluminium recycling capacity',
#  249: 'Alro',
#  250: 'Lech',
#  251: 'ArcelorMittal',
#  252: 'electricity price peak',
#  253: 'German Chamber of Industry',
#  254: 'German Chamber of Commerce',
#  255: 'Heinz Glass',
#  256: 'perfume industry',
#  257: 'energy prices',
#  258: 'electricity',
#  259: 'electricity imports',
#  260: '2022 2023',
#  261: 'cement imports',
#  262: 'Russian',
#  263: 'crude steel imports',
#  264: 'carbon border adjustment mechanism',
#  265: 'EU climate policy',
#  266: 'carbon pricing policies',
#  267: 'firms',
#  268: 'data centre growth',
#  269: 'internet of things',
#  270: 'Frankfurt',
#  271: 'data centre sector',
#  272: 'data',
#  273: 'Commission for Regulation of Utilities',
#  274: 'new data centre grid connection applications',
#  275: 'data centre grid connection applications',
#  276: 'pan European',
#  277: 'Norway',
#  278: 'Finland',
#  279: 'Nordic',
#  280: 'Stockholm',
#  281: 'data centre',
#  282: 'company',
#  283: 'data centre market',
#  284: 'Northern Virginia',
#  285: '2040',
#  286: 'Amazon',
#  287: 'data centre developments',
#  288: 'PJM',
#  289: '2034',
#  290: 'market trends',
#  291: 'NVIDIA',
#  292: 'ai industry',
#  293: 'Ethereum',
#  294: 'energy efficiency directive',
#  295: 'data centre pact',
#  296: 'energy act of 2020',
#  297: 'water use',
#  298: 'data centre energy',
#  299: 'water usage',
#  300: 'carbon emissions reductions',
#  301: 'Virginia',
#  302: 'Oregon',
#  303: 'data centre cooling',
#  304: 'Google',
#  305: 'deepmind ai',
#  306: 'global market',
#  307: 'emission energy',
#  308: 'emission energy production',
#  309: 'solar pv generation',
#  310: 'smart meter investments',
#  311: '2018',
#  312: 'lng supply',
#  313: 'chinese demand growth',
#  314: 'new coal plants',
#  315: 'Bangladesh',
#  316: 'Pakistan',
#  317: 'new capacity',
#  318: '2050',
#  319: 'mineral supply',
#  320: 'uranium',
#  321: 'Shidaowan',
#  322: '2032',
#  323: 'Rooppur',
#  324: 'fuel shipment',
#  325: 'political landscape',
#  326: 'nuclear power',
#  327: 'EU Council',
#  328: 'European Parliament',
#  329: 'european pressurised reactors',
#  330: 'Swedish',
#  331: '2045',
#  332: 'Belgium nuclear',
#  333: 'Loviisa',
#  334: 'Krško Nuclear Station',
#  335: 'Slovenia',
#  336: 'new nuclear',
#  337: 'Bulgaria',
#  338: '2053',
#  339: 'Kozloduy',
#  340: 'steps',
#  341: 'Khmelnitsky',
#  342: 'Cabinet',
#  343: 'Turkey Point',
#  344: 'Florida',
#  345: '2029 2030',
#  346: '2027',
#  347: 'Argentina',
#  348: 'Atucha',
#  349: 'Hinkley Point C',
#  350: 'French',
#  351: 'El Dabaa',
#  352: 'financing instruments',
#  353: 'European parliament',
#  354: 'financing challenges',
#  355: 'carem25',
#  356: 'Utah Associated Municipal Power Systems',
#  357: 'NuScale',
#  358: 'smr 300',
#  359: 'Palisades',
#  360: 'Michigan',
#  361: 'Holtec International',
#  362: 'Hitachi',
#  363: 'bwrx',
#  364: 'Ontario',
#  365: 'Point Lepreau',
#  366: 'New Brunswick Power',
#  367: 'Romania',
#  368: 'Industrial Alliance',
#  369: 'Export Import Bank',
#  370: 'fast neutron spectrum',
#  371: 'Seversk',
#  372: 'generation iii reactors',
#  373: 'Colombia',
#  374: 'Costa Rica',
#  375: 'Türkiye',
#  376: 'electricity supply stability',
#  377: 'power crisis',
#  378: 'Vietnam',
#  379: 'hydropower shortage',
#  380: 'el niño southern oscillation',
#  381: 'Colombia annual electricity production',
#  382: 'el niño',
#  383: 'hydropower output costa rica',
#  384: 'stated policies scenario',
#  385: 'hydrogen power',
#  386: 'gas turbine',
#  387: 'Siemens',
#  388: 'hydrogen',
#  389: 'Kawasaki Heavy Industries',
#  390: 'GE',
#  391: 'GE Energy',
#  392: 'gas turbine manufacturers',
#  393: 'Birr',
#  394: 'Greenville',
#  395: 'Berlin',
#  396: 'Finspång',
#  397: 'North Carolina',
#  398: 'gas turbines',
#  399: 'Siemens Dammam Energy Hub',
#  400: 'Harbin Turbine Company',
#  401: 'Dongfang Electric Corp',
#  402: 'Power Machines',
#  403: 'trade volume',
#  404: 'Siemens Gas Turbine',
#  405: 'solar energy',
#  406: 'cobalt supplies',
#  407: 'Democratic Republic of the Congo',
#  408: 'cobalt',
#  409: 'fossil fired',
#  410: 'global electricity sector emissions',
#  411: 'China emissions electricity generation',
#  412: 'renewables deployment',
#  413: 'energy commodity prices',
#  414: '2005',
#  415: 'total emissions',
#  416: 'price levels',
#  417: 'higher prices',
#  418: 'Scandinavia',
#  419: '2019 2026',
#  420: 'lng import prices',
#  421: 'coal prices',
#  422: 'futures prices',
#  423: 'German',
#  424: 'energy crisis 2019',
#  425: 'ARENH',
#  426: 'EDF',
#  427: 'market prices',
#  428: 'power exports',
#  429: 'carbon costs',
#  430: 'carbon price burden',
#  431: 'aid schemes',
#  432: 'electricity cost',
#  433: 'policy changes',
#  434: 'solidarity shield',
#  435: 'power prices',
#  436: 'power supply availabilities',
#  437: 'fuel supply issues',
#  438: 'AEMO',
#  439: 'ds3',
#  440: 'North American Electric Reliability Corporation',
#  441: '2020',
#  442: 'investment cost',
#  443: 'electricity bills',
#  444: 'Maine',
#  445: 'Massachusetts',
#  446: 'Gujarat',
#  447: 'cyclone biparjoy',
#  448: 'Michaung',
#  449: 'Andhra Pradesh',
#  450: 'distribution system',
#  451: 'Karnataka',
#  452: 'BESCOM',
#  453: 'Kenya Power',
#  454: 'gas shortages',
#  455: 'Kazakhstan',
#  456: 'Kyrgyzstan',
#  457: 'oil',
#  458: 'Madagascar',
#  459: 'fuel shortages winter months',
#  460: 'Yemen',
#  461: 'fuel shortages',
#  462: 'Hong Kong ’s Long Island',
#  463: 'HK Electric',
#  464: 'data breaches',
#  465: 'FERC',
#  466: 'Asia Pacific',
#  467: 'electricity use',
#  468: 'low carbon sources',
#  469: 'electricity generation co2 intensity',
#  470: 'industry sector',
#  471: 'pv modules',
#  472: 'total generation',
#  473: 'coal power facilities',
#  474: 'wind china',
#  475: 'solar china',
#  476: 'lng market',
#  477: 'solar european union 2022',
#  478: 'solar united states 2022',
#  479: '20232024 winter period',
#  480: 'National Energy Administration',
#  481: 'spot market rules',
#  482: 'NEA',
#  483: 'renewable energy generation',
#  484: 'Kakrapar Unit 3 reactor',
#  485: '2024 2026',
#  486: 'national electricity plan',
#  487: 'Central Electricity Authority',
#  488: 'Ministry of Power',
#  489: 'II',
#  490: 'Nepal',
#  491: 'power trade',
#  492: 'g20 new delhi leaders ’ declaration',
#  493: 'HP DAM',
#  494: 'gas power',
#  495: 'coal power',
#  496: 'battery energy storage',
#  497: 'CERC',
#  498: 'emission intensity',
#  499: 'Japanese',
#  500: 'gas bills',
#  501: 'Ministry of Economy',
#  502: 'Ministry of Trade',
#  503: 'Ministry of Industry',
#  504: 'total power capacity',
#  505: 'special act on expansion of the national power grid',
#  506: 'National Assembly',
#  507: 'market design',
#  508: 'Korea Power Exchange',
#  509: 'battery projects',
#  510: 'National Electricity Market',
#  511: 'renewables generation',
#  512: 'electricity consumer',
#  513: 'electricity generation mix',
#  514: 'grid electricity demand',
#  515: '2022 2050',
#  516: 'electricity demand gains',
#  517: 'coal generation',
#  518: 'gas prices',
#  519: 'Northern Viet Nam',
#  520: 'cross border electricity exports',
#  521: 'gas production',
#  522: 'Erawan',
#  523: 'PTT Exploration',
#  524: 'Production',
#  525: 'solar capacity',
#  526: 'data centre investments',
#  527: 'national energy transition roadmap',
#  528: 'Malaysian',
#  529: 'transport sector',
#  530: 'Tenaga Nasional Berhad',
#  531: 'transition fuel',
#  532: 'Singapore',
#  533: 'Americas',
#  534: 'IRA',
#  535: 'clean energy manufacturing projects',
#  536: 'Henry Hub',
#  537: '2011',
#  538: 'wind generation',
#  539: 'Unit',
#  540: 'electricity supply winter',
#  541: 'electricity exports',
#  542: 'Quebec',
#  543: 'British Columbia',
#  544: 'heating oil',
#  545: 'heat pumps',
#  546: 'renewable energy supply',
#  547: 'fuel sources',
#  548: 'fuel oil',
#  549: '2017',
#  550: 'wind solar pv generation 2022',
#  551: 'northeast',
#  552: 'State Grid',
#  553: '2018 2022 average',
#  554: 'coal power phase',
#  555: 'Chilean',
#  556: 'electricity tariffs',
#  557: 'higher electricity prices',
#  558: 'Ecuador',
#  559: 'electricity security',
#  560: 'covid 19 pandemic',
#  561: 'electricity suppliers',
#  562: 'electricity company',
#  563: 'Malta',
#  564: 'European Energy Markets',
#  565: 'European Council',
#  566: 'Council',
#  567: 'new power',
#  568: 'new renewable energy directive',
#  569: 'renewable energy',
#  570: 'building sector',
#  571: 'renewable energy 2030',
#  572: 'action plan for grids',
#  573: 'wind deployments',
#  574: 'electricity tariff',
#  575: '2022 power price highs',
#  576: '2017 2021 average',
#  577: 'electricity exporter',
#  578: 'wind production',
#  579: 'renewable acceleration bill',
#  580: 'Italian',
#  581: 'fuel source',
#  582: 'coal plants',
#  583: 'Naturgy',
#  584: 'Spanish Supreme Court',
#  585: 'UK',
#  586: 'Britain',
#  587: 'electricity consumption growth',
#  588: 'Greater Dublin',
#  589: 'TSO EirGrid',
#  590: 'Dublin gas',
#  591: 'Wales',
#  592: 'wind power generation',
#  593: 'wind conditions',
#  594: 'North Sea',
#  595: 'Europe coal electricity producer',
#  596: 'Belarus',
#  597: 'Russia Far East',
#  598: 'fossil',
#  599: 'wind power output',
#  600: 'Western Kazakhstan',
#  601: 'electricity grid infrastructure',
#  602: 'Inter RAO',
#  603: 'Ministry of Energy',
#  604: 'electricity supply security',
#  605: 'Turkmenistan',
#  606: 'Afghanistan',
#  607: 'electricity supplies',
#  608: 'power generation emissions',
#  609: 'fossil fuel use',
#  610: 'desalination capacity',
#  611: 'desalination capacity target',
#  612: 'commission',
#  613: 'emission hydrogen',
#  614: 'Kingdom',
#  615: 'UAE',
#  616: 'Dubai',
#  617: 'Emirates Water and Electricity Company',
#  618: 'Abu Dhabi',
#  619: 'power emissions',
#  620: 'Dhafra',
#  621: 'mosques',
#  622: 'Gulf Electricity Interconnection Expansion Project',
#  623: 'Israel',
#  624: 'solar power plant',
#  625: 'qatar national vision',
#  626: 'renewable energy sources',
#  627: 'Mesaieed',
#  628: 'Ras Laffan',
#  629: 'QatarEnergy',
#  630: 'solar pv plant',
#  631: 'wind farm',
#  632: 'Rabt',
#  633: 'Suwayhat',
#  634: 'Oman Electricity Transmission Company',
#  635: 'electricity subsidies',
#  636: 'Eskom',
#  637: 'Vodacom',
#  638: 'renewable energy projects',
#  639: 'Egyptian',
#  640: 'NWFE',
#  641: '2023 2028',
#  642: 'fossil fuel capacity',
#  643: 'vision 2030',
#  644: 'Algeria',
#  645: 'power sector emissions',
#  646: 'Corso',
#  647: 'Algerian Energy Company',
#  648: 'Morocco',
#  649: 'investment plan',
#  650: 'Moroccan',
#  651: 'Shell',
#  652: 'Nigeria',
#  653: 'fossil fuel subsidies',
#  654: 'bola tinubu',
#  655: 'Energizing Economies Initiative',
#  656: 'Nigerian Rural Electrification Agency',
#  657: 'West Africa',
#  658: 'new electricity act 2023',
#  659: '2038',
#  660: 'integrated low cost plan',
#  661: 'Just Energy Transition Partnership',
#  662: 'minerals',
#  663: 'clean energy applications',
#  664: 'lithium',
#  665: 'nickel',
#  666: 'iea scenarios',
#  667: 'electric car sales',
#  668: 'electric cars',
#  669: 'announced pledges scenario',
#  670: 'nze scenario',
#  671: 'graphite demand',
#  672: 'copper production',
#  673: 'lithium production',
#  674: 'battery metals such lithium',
#  675: 'APS',
#  676: 'benchmark',
#  677: 'mine supply',
#  678: 'battery grade',
#  679: 'earth',
#  680: 'market concentration',
#  681: 'nickel production',
#  682: 'cobalt production',
#  683: 'battery prices',
#  684: 'energy transition minerals',
#  685: 'Outlook',
#  686: 'geopolitical risks',
#  687: 'ev batteries',
#  688: 'minerals market',
#  689: 'trade restriction measures',
#  690: 'clean energy technologies',
#  691: 'material prices',
#  692: 'clean energy summit',
#  693: 'market situation',
#  694: 'market monitoring',
#  695: 'Group of Seven',
#  696: 'minerals security',
#  697: 'UN',
#  698: 'clean energy deployment',
#  699: 'People ’s Republic of China',
#  700: 'solar pv additions',
#  701: 'policy environment',
#  702: 'solar pv capacity additions',
#  703: 'supply chain',
#  704: 'wind capacity additions',
#  705: 'wind projects',
#  706: 'electrolysis projects',
#  707: 'electric car market',
#  708: 'export markets',
#  709: 'electric car sales shares',
#  710: 'battery electric vehicles',
#  711: 'United States battery electric vehicles',
#  712: 'ev sales',
#  713: 'phev demand',
#  714: 'battery size',
#  715: 'battery size europe',
#  716: 'evs',
#  717: 'erevs',
#  718: 'electric vehicle',
#  719: 'policy momentum',
#  720: 'cost declines',
#  721: 'global battery demand',
#  722: 'global demand',
#  723: 'battery demand',
#  724: 'battery storage',
#  725: 'battery sizes',
#  726: 'battery pack prices',
#  727: 'battery pack cost',
#  728: 'battery pack price',
#  729: 'mineral price volatility',
#  730: 'blade battery',
#  731: 'BYD',
#  732: 'ev vehicles',
#  733: 'manganese',
#  734: 'sodium ion',
#  735: 'CATL',
#  736: 'Northvolt',
#  737: 'sodium ion chemistries',
#  738: 'lithium prices',
#  739: 'sodium ion batteries',
#  740: 'lithium ion',
#  741: 'Samsung',
#  742: 'scale production',
#  743: 'battery supply chain',
#  744: 'battery minerals',
#  745: 'battery cell production capacity',
#  746: 'material production',
#  747: 'battery plants',
#  748: 'export market',
#  749: 'battery storage market',
#  750: 'battery storage capacity',
#  751: 'lithium ion batteries',
#  752: 'battery manufacturers',
#  753: 'battery market',
#  754: 'market conditions',
#  755: 'copper concentrates',
#  756: 'copper producers',
#  757: 'raw material production',
#  758: 'nickel mining',
#  759: 'nickel mine',
#  760: 'cobalt supply',
#  761: 'Glencore',
#  762: 'CMOC',
#  763: 'copper output',
#  764: 'copper supply',
#  765: 'concentrate markets',
#  766: 'scrap market',
#  767: 'Finniss',
#  768: 'Core Lithium',
#  769: 'Albemarle',
#  770: 'cost cutting',
#  771: 'Talison',
#  772: 'stainless steel demand',
#  773: 'nickel supply',
#  774: 'production growth',
#  775: 'output growth',
#  776: 'Indonesia production growth',
#  777: 'HPAL',
#  778: 'lme price',
#  779: 'LME',
#  780: 'nickel products',
#  781: 'higher cost producers',
#  782: 'Panoramic Resources',
#  783: 'West Australia',
#  784: 'Nickel West',
#  785: 'BHP',
#  786: 'West Musgrave',
#  787: 'nickel market',
#  788: 'cobalt prices',
#  789: 'DRC',
#  790: 'battery sector',
#  791: 'Kisanfu',
#  792: 'production volume growth',
#  793: 'Lac des Îles',
#  794: 'Balama',
#  795: 'Mozambique',
#  796: 'POSCO',
#  797: 'Louisiana',
#  798: 'ira',
#  799: 'ree market',
#  800: 'rare earth technologies',
#  801: 'ree markets',
#  802: 'Myanmar',
#  803: 'Laos',
#  804: 'policy landscape',
#  805: 'Western',
#  806: 'Russia nuclear supply chain',
#  807: 'uranium',
#  808: 'conversion industry',
#  809: 'battery packs',
#  810: 'production cash costs',
#  811: 'production costs',
#  812: 'vc investment',
#  813: 'battery recycling space',
#  814: 'cobalt extraction',
#  815: 'Kobold Metals',
#  816: 'Energy Exploration Technologies',
#  817: 'lithium extraction',
#  818: 'GM Ventures',
#  819: 'nickel extraction technologies',
#  820: 'Atlas Materials',
#  821: 'battery metals such',
#  822: 'Africa',
#  823: 'Arcadia',
#  824: 'Zimbabwe',
#  825: 'Zijin Mining',
#  826: 'Neo Lithium',
#  827: 'lithium project',
#  828: 'Indonesia battery nickel output',
#  829: 'lithium producer',
#  830: 'SHFE',
#  831: 'demand growth',
#  832: 'metals exchanges',
#  833: 'LME March 2022',
#  834: 'CME',
#  835: 'commodities market',
#  836: 'market players',
#  837: 'esg',
#  838: 'producer economies',
#  839: 'minerals strategies',
#  840: 'market entrants',
#  841: 'african green minerals strategy',
#  842: 'African Minerals Development Centre',
#  843: 'minerals strategy',
#  844: 'Zambia',
#  845: 'Critical Minerals Facility',
#  846: 'World Trade Organization',
#  847: 'Namibia',
#  848: 'lithium exports',
#  849: 'export restrictions',
#  850: 'export controls',
#  851: 'resource diplomacy guidance',
#  852: 'African',
#  853: 'metals equity',
#  854: 'Corporate Sustainability Reporting Directive',
#  855: 'corporate sustainability due diligence directive',
#  856: 'csddd',
#  857: 'Estonia',
#  858: 'MSP',
#  859: 'statement of intent',
#  860: 'sustainable investment facilitation agreements',
#  861: 'trade agreements',
#  862: 'battery producer basf',
#  863: 'mining industry',
#  864: 'minerals supply',
#  865: 'emissions 2030',
#  866: 'industry players',
#  867: 'esg goals',
#  868: 'emissions management',
#  869: 'clean energy transitions',
#  870: 'supply chain bottlenecks',
#  871: 'chapter',
#  872: 'emissions power sources',
#  873: 'grid investment growth',
#  874: 'sales growth',
#  875: 'ev battery demand',
#  876: '2023 steps',
#  877: '2023 aps',
#  878: 'electric trucks',
#  879: 'global storage demand 2050',
#  880: 'battery production capacity',
#  881: 'battery supply chains',
#  882: 'price competition',
#  883: 'electric car',
#  884: 'range market',
#  885: 'Manganese',
#  886: 'ev battery market',
#  887: 'ev market',
#  888: 'mineral demand',
#  889: 'total demand',
#  890: 'clean energy sector',
#  891: 'total lithium demand',
#  892: 'lithium market',
#  893: 'foreign entities of concern',
#  894: 'copper demand',
#  895: 'refined copper demand',
#  896: 'electricity networks',
#  897: 'Peru',
#  898: 'copper resources',
#  899: 'copper mines',
#  900: 'Kamoa Kakula',
#  901: 'Escondida',
#  902: 'PT Freeport Indonesia',
#  903: 'Collahuasi',
#  904: 'mine production',
#  905: 'Cobre Panama',
#  906: 'Las Bambas',
#  907: 'copper mine',
#  908: 'copper refiner',
#  909: 'copper miner',
#  910: 'copper concentrate',
#  911: '2012',
#  912: 'copper refineries',
#  913: 'Guixi',
#  914: 'Jinchuan',
#  915: 'Onsan',
#  916: 'Ventanas',
#  917: 'Codelco',
#  918: 'ore quality',
#  919: 'operating costs',
#  920: 'capital costs',
#  921: 'copper projects',
#  922: 'cost advantages',
#  923: 'covid',
#  924: 'copper scrap use',
#  925: 'policy mandates',
#  926: 'policy efforts',
#  927: 'investment side',
#  928: 'lithium demand',
#  929: 'ev industry',
#  930: 'lithium demand growth',
#  931: 'ev sector',
#  932: 'APS 2030',
#  933: 'vanadium flow technologies',
#  934: 'lithium metal anodes',
#  935: 'raw material supply',
#  936: 'Kathleen Valley',
#  937: 'Mount Holland',
#  938: 'Greenbushes',
#  939: 'Salar de Atacama',
#  940: 'brine extraction projects',
#  941: 'capital investments lithium latin america',
#  942: 'Bolivia',
#  943: 'policy incentives',
#  944: 'recycling companies',
#  945: 'eu battery regulation',
#  946: 'lithium carbonate production',
#  947: 'mining projects',
#  948: 'North America',
#  949: 'Australian',
#  950: 'Argentinian',
#  951: 'lithium market structure',
#  952: 'to the respective market shares battery chemistries',
#  953: 'ev',
#  954: 'global nickel demand',
#  955: '2020 to 2023',
#  956: 'nickel demand',
#  957: 'APS NZE Scenario',
#  958: 'nickel use',
#  959: 'nickel output',
#  960: '2018 2023',
#  961: 'battery cathodes',
#  962: 'nickel metals',
#  963: 'nickel product production',
#  964: 'nickel sulphate production',
#  965: 'mhp production',
#  966: 'matte production',
#  967: 'nickel producers',
#  968: 'nickel prices',
#  969: 'nickel mines',
#  970: 'total supply loss',
#  971: 'RKEF',
#  972: 'mt co2 emissions nickel production indonesia',
#  973: 'absolute co2 emissions',
#  974: 'emissions alternatives',
#  975: 'Indonesian',
#  976: 'Minviro',
#  977: 'job creation',
#  978: 'coal power',
#  979: 'nickel smelters',
#  980: 'Morowali Industrial Park',
#  981: 'Central Sulawesi',
#  982: 'Obi Island',
#  983: 'Weda Bay',
#  984: 'indonesian taxonomy for sustainable finance',
#  985: 'market stakeholders',
#  986: 'market liquidity',
#  987: 'London Metal Exchange',
#  988: 'Metalshub',
#  989: 'metals procurement',
#  990: 'market participants',
#  991: 'price assessments',
#  992: 'Fastmarkets',
#  993: 'Benchmark Mineral Intelligence',
#  994: 'Benchmark',
#  995: 'emissions thresholds',
#  996: 'nickel production tax credits',
#  997: 'carbon tax',
#  998: 'disclosure policies',
#  999: 'battery producers',
#  ...}
